# %%
import seaborn as sns

# %%
planets = sns.load_dataset('planets')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/miniconda3/envs/p3/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1341             try:
# -> 1342                 h.request(req.get_method(), req.selector, req.data, headers,
#    1343                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~/miniconda3/envs/p3/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~/miniconda3/envs/p3/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ...
